# %%
# Load library
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
import re

import matplotlib.pyplot as plt
# %matplotlib inline  
from  matplotlib import style

from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})

# %%
# read all six csv files
df_sea = pd.read_csv("tweets/seattle_tweets.csv", encoding="latin1")
df_sea = pd.DataFrame(df_sea)
df_sad = pd.read_csv("tweets/sandiego_tweets.csv", encoding="latin1")
df_sad = pd.DataFrame(df_sad)
df_den = pd.read_csv("tweets/denver_tweets.csv", encoding="latin1")
df_den = pd.DataFrame(df_den)
df_chi = pd.read_csv("tweets/chicago_tweets.csv", encoding="latin1")
df_chi = pd.DataFrame(df_chi)
df_por = pd.read_csv("tweets/portland_tweets.csv", encoding="latin1")
df_por = pd.DataFrame(df_por)
df_aus = pd.read_csv("tweets/austin_tweets.csv", encoding="latin1")
df_aus = pd.DataFrame(df_aus)

# %%
# add a column for each respective city of the top six
df_sea['city'] = "Seattle"
df_sad['city'] = "San Diego"
df_den['city'] = "Denver"
df_chi['city'] = "Chicago"
df_por['city'] = "Portland"
df_aus['city'] = "Austin"

# %%
# concat csv files 
frames_cities = df_sea,df_sad,df_den,df_chi,df_por,df_aus
df_tweets = pd.concat(frames_cities)

# %%
# inspect head of df
df_tweets.head()
# Out:
#                   name                 time  \
# 0  1030995577981435906  2018-08-19 01:51:15
# 1  1030962792415866880  2018-08-18 23:40:58
# 2  1030958589467406337  2018-08-18 23:24:16
# 3  1030953374148165633  2018-08-18 23:03:33
# 4  1030944029788332032  2018-08-18 22:26:25
#
#                                                tweet  \
# 0  RT @flyingbikecoop: 3rd Anniversary Party toda...
# 1  Mystery keg #1 is tapped! Pitchfork is our wil...
# 2  3 years old!! #proudmemberowner - Drinking a S...
# 3  #MemberDrivenBeer celebrating 3 years! - Drink...
# 4  #MemberDrivenBeer Stout Float :-D - Drinking a...
#
#                                                  geo                   id  \
# 0                                                NaN  1030995577981435906
# 1  {'type': 'Point', 'coordinates': [47.69208753,...  1030962792415866880
# 2  {'type': 'Point', 'coordinates': [47.6921, -12...  1030958589467406337
# 3                                                NaN  1030953374148165633
# 4                                                NaN  1030944029788332032
#
#                source     city
# 0  Twitter for iPhone  Seattle
# 1           Instagram  Seattle
# 2             Untappd  Seattle
# 3             Untappd  Seattle
# 4             Untappd  Seattle

# %%
# inspect shape of df
df_tweets.shape
# Out:
# (6280, 7)

# %%
#import other python packages and libraries to do wordclouds, wordcounts, and remove stopwords
from os import path
from scipy.misc import imread
import random
from wordcloud import WordCloud, STOPWORDS

# %%
#import other python packages and libraries to do wordclouds, wordcounts, and remove stopwords
import nltk
import re
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

# %%
# define a function that cleans the tweets
def preprocess(raw_text):

    # keep only words
    letters_only_text = re.sub("[^a-zA-Z]", " ", raw_text)
    
    # convert to lower case and split 
    words = letters_only_text.lower().split()

    # remove stopwords
    stopword_set = set(stopwords.words("english"))
    meaningful_words = [w for w in words if w not in stopword_set]

    # join the cleaned words in a list
    cleaned_word_list = " ".join(meaningful_words)

    return cleaned_word_list

# %%
# use apply function to apply the preprocess function
df_tweets['clean_tweet'] = df_tweets.tweet.apply(preprocess)

# %%
# use apply function to apply the len function
df_tweets['tweet_len'] = df_tweets.tweet.apply(len)

# %%
# use apply function to add a column which tells us if tweet contains RT
df_tweets['retweet'] = df_tweets.tweet.str.contains("RT")

# %%
# use apply function to add a column which tells us if tweet contains @ symbol
df_tweets['at_brewery'] = df_tweets.tweet.str.contains("@")

# %%
# use apply function to add a column which tells us if tweet contains the word drinking
df_tweets['drinking'] = df_tweets.clean_tweet.str.contains("drinking")

# %%
# drop geo and name columns 
df_tweets = df_tweets.drop(columns=['geo','name'])

# %%
# drop duplicate observations
df_tweets = df_tweets.drop_duplicates()

# %%
# print head 
df_tweets[0:200]
# Out:
#                     time                                              tweet  \
# 0    2018-08-19 01:51:15  RT @flyingbikecoop: 3rd Anniversary Party toda...
# 1    2018-08-18 23:40:58  Mystery keg #1 is tapped! Pitchfork is our wil...
# 2    2018-08-18 23:24:16  3 years old!! #proudmemberowner - Drinking a S...
# 3    2018-08-18 23:03:33  #MemberDrivenBeer celebrating 3 years! - Drink...
# 4    2018-08-18 22:26:25  #MemberDrivenBeer Stout Float :-D - Drinking a...
# 5    2018-08-18 22:25:49  See you soon for our Third Birthday Party! \n4...
# 6    2018-08-18 21:21:14  #MemberDrivenBeer 3rd Anniversary - Drinking a...
# 7    2018-08-18 21:03:07  3rd Anniversary Party today! Bring all your fr...
# 8    2018-08-17 18:22:05  Updated Beer List! Come have some fun with us ...
# 9    2018-08-17 17:19:23  Come have some fun with us tonight and enjoy t...
# 10   2018-08-16 23:02:48  Hey Members, get a punch on your Frequent Flye...
# 11   2018-08-16 14:56:16  @flyingbikecoop sounds like a great place! Con...
# 12   2018-08-16 04:28:51  Third Anniversary Critical Mass Run Club was o...
# 13   2018-08-15 21:59:42  Woohoo! Happy anniversary @flyingbikecoop! htt...
# 14   2018-08-15 03:30:05  RT @beerblog: This week @flyingbikecoop celebr...
# 15   2018-08-15 03:05:00  This week @flyingbikecoop celebrates 3rd Anniv...
# 16   2018-08-15 02:58:29  Hot off the presses! Thanks to @beerblog for l...
# 17   2018-08-15 00:15:00  This week @flyingbikecoop celebrates 3rd Anniv...
# 18   2018-08-14 16:44:23  This week @flyingbikecoop celebrates 3rd Anniv...
# 19   2018-08-12 15:53:09  RT @barbchamberlain: A #bikeschool #SEAbikes m...
# 20   2018-08-10 05:03:08  RT @leedscath: TONIGHT! From 8pm PT #seattle f...
# 21   2018-08-10 04:50:31  Beer today @flyingbikecoop in Seattle, kombuch...
# 22   2018-08-10 01:47:45  TONIGHT! From 8pm PT #seattle folk wanting to ...
# 23   2018-08-10 00:40:28  Our @WashingtonBeer award winning brown on tap...
# 200  2018-08-14 20:07:48  @twobeersbrewing stopped by today with a RAD s...
# 201  2018-08-14 19:16:43  Join @REI at The Woods this Thursday for a nig...
# 203  2018-08-13 23:51:58  Two Beers Fresh Hop IPA  (@twobeersbrewing)  i...
#
#                       id                  source     city  \
# 0    1030995577981435906      Twitter for iPhone  Seattle
# 1    1030962792415866880               Instagram  Seattle
# 2    1030958589467406337                 Untappd  Seattle
# 3    1030953374148165633                 Untappd  Seattle
# 4    1030944029788332032                 Untappd  Seattle
# 5    1030943879732899840               Instagram  Seattle
# 6    1030927628293873664                 Untappd  Seattle
# 7    1030923065188708352      Twitter for iPhone  Seattle
# 8    1030520154109698048               Instagram  Seattle
# 9    1030504376903688192               Instagram  Seattle
# 10   1030228409635364864               Instagram  Seattle
# 11   1030105971035709440      Twitter Web Client  Seattle
# 12   1029948077115756544               Instagram  Seattle
# 13   1029850143317614593      Twitter Web Client  Seattle
# 14   1029570897743511552      Twitter for iPhone  Seattle
# 15   1029564586138251265               TweetDeck  Seattle
# 16   1029562945708204032                  Buffer  Seattle
# 17   1029521804014968832               TweetDeck  Seattle
# 18   1029408403905339393               TweetDeck  Seattle
# 19   1028670733663137792      Twitter for iPhone  Seattle
# 20   1027782376032796672  5b37d2a786aeb453738826  Seattle
# 21   1027779202861297664     Twitter for Android  Seattle
# 22   1027733208585003008               TweetDeck  Seattle
# 23   1027716274845962242      Twitter for iPhone  Seattle
# 24   1030939935426007040      Twitter for iPhone  Seattle
# 25   1030939860045979648      Twitter for iPhone  Seattle
# 26   1030939851812626432      Twitter for iPhone  Seattle
# 27   1030938974750171136                 Untappd  Seattle
# 28   1030937945660899329                 Untappd  Seattle
# 29   1030663378174398464           WordPress.com  Seattle
# ..                   ...                     ...      ...
# 173  1030469820616073219      Twitter Web Client  Seattle
# 174  1030469198596661249      Twitter Web Client  Seattle
# 175  1030263440655306753               TweetDeck  Seattle
# 176  1030253731760107520      Twitter for iPhone  Seattle
# 177  1030253407213252608      Twitter for iPhone  Seattle
# 178  1030252956736602112               Instagram  Seattle
# 179  1030247535158292480      Twitter Web Client  Seattle
# 180  1030247416006508544      Twitter Web Client  Seattle
# 181  1030244448234393600      Twitter Web Client  Seattle
# 182  1030244035460358145      Twitter Web Client  Seattle
# 183  1030236831319609344         DPBeerDashboard  Seattle
# 184  1030236829918740480         DPBeerDashboard  Seattle
# 185  1030208061561073664                 Untappd  Seattle
# 186  1030200618055421952     Twitter for Android  Seattle
# 187  1030179425583656960      Twitter Web Client  Seattle
# 188  1030177270302793728      Twitter Web Client  Seattle
# 189  1030139907681935360      Twitter for iPhone  Seattle
# 190  1030137513061609473               Instagram  Seattle
# 191  1029955417596669953                 Untappd  Seattle
# 192  1029942478781050880      Twitter for iPhone  Seattle
# 193  1029810993474334720      Twitter Web Client  Seattle
# 184  two beers fresh hop ipa twobeersbrewing replac...        105    False
# 185  drinking fresh hop ipa twobeersbrewing theredh...         96    False
# 186  first fresh hop ipa season twobeersbrewing sto...         89    False
# 187  sister company seattleciderco turns five next ...        144    False
# 188  rt hophousered fresh hop twobeersbrewing leads...        145     True
# 189  rt nwgrowlers yes time year freshhops twobeers...        145     True
# 190  yes time year freshhops twobeersbrewing fh alw...        144    False
# 191  drinking wonderland trail ipa twobeersbrewing ...         98    False
# 192  fresh hop twobeersbrewing leads pack freshest ...        145    False
# 193  imthehappiestwhen enjoying twobeersinthewild h...         71    False
# 194  kylemallory twobeersbrewing belmontstation wow...         82    False
# 195  bine beer amp food thebinebothell two beers ta...        149    False
# 196  two beers tangerine citra pale twobeersbrewing...        107    False
# 197  toshjohn first fresh hop arrived via twobeersb...        144    False
# 198  billy baroos billybbrews two beers fresh hop i...        129    False
# 199  two beers fresh hop ipa twobeersbrewing replac...        100    False
# 200  twobeersbrewing stopped today rad special deli...        145    False
# 201  join rei woods thursday night drinks food give...        143    False
# 203  two beers fresh hop ipa twobeersbrewing replac...        102    False
#
#      at_brewery  drinking
# 0          True     False
# 1         False     False
# 2          True      True
# 3          True      True
# 4          True      True
# 5         False     False
# 6          True      True
# 7         False     False
# 8         False     False
# 9         False     False
# 10        False     False
# 11         True     False
# 12        False     False
# 13         True     False
# 14         True     False
# 15         True     False
# 16         True     False
# 17         True     False
# 18         True     False
# 19         True     False
# 20         True     False
# 21         True     False
# 22        False     False
# 23         True     False
# 24         True     False
# 25         True      True
# 26         True      True
# 27         True      True
# 28         True      True
# 29        False     False
# ..          ...       ...
# 173        True     False
# 174        True     False
# 175        True     False
# 176        True     False
# 177        True     False
# 178        True     False
# 179        True     False
# 180        True     False
# 181        True     False
# 182        True     False
# 183        True     False
# 184        True     False
# 185        True      True
# 186        True     False
# 187        True     False
# 188        True     False
# 189        True     False
# 190        True     False
# 191        True      True
# 192        True     False
# 193       False     False
# 194        True     False
# 195        True     False
# 196        True     False
# 197        True     False
# 198        True     False
# 199        True     False
# 200        True     False
# 201        True     False
# 203        True     False
#
# [200 rows x 10 columns]

# %%
# create function to find the word Drinking and returning the strings that follow and stoping at the word by
def findcraft(beer_text):
    drinking_word_pos = beer_text.find('Drinking a') 
    at_pos = beer_text.find('by')
    craft_beer_drinking = beer_text[drinking_word_pos:at_pos]
    return craft_beer_drinking

# %%
# apply function to df
df_tweets['craft_beer'] = df_tweets.tweet.apply(findcraft)

# %%
# print head to inspect
df_tweets.head()
# Out:
#                   time                                              tweet  \
# 0  2018-08-19 01:51:15  RT @flyingbikecoop: 3rd Anniversary Party toda...
# 1  2018-08-18 23:40:58  Mystery keg #1 is tapped! Pitchfork is our wil...
# 2  2018-08-18 23:24:16  3 years old!! #proudmemberowner - Drinking a S...
# 3  2018-08-18 23:03:33  #MemberDrivenBeer celebrating 3 years! - Drink...
# 4  2018-08-18 22:26:25  #MemberDrivenBeer Stout Float :-D - Drinking a...
#
#                     id              source     city  \
# 0  1030995577981435906  Twitter for iPhone  Seattle
# 1  1030962792415866880           Instagram  Seattle
# 2  1030958589467406337             Untappd  Seattle
# 3  1030953374148165633             Untappd  Seattle
# 4  1030944029788332032             Untappd  Seattle
#
#                                          clean_tweet  tweet_len  retweet  \
# 0  rt flyingbikecoop rd anniversary party today b...        107     True
# 1  mystery keg tapped pitchfork wild golden stron...        145    False
# 2  years old proudmemberowner drinking storm cycl...        130    False
# 3  memberdrivenbeer celebrating years drinking cu...        134    False
# 4  memberdrivenbeer stout float drinking mocha mi...        133    False
#
#    at_brewery  drinking                    craft_beer
# 0        True     False
# 1       False     False
# 2        True      True   Drinking a Storm Cycle CDA
# 3        True      True      Drinking a Curry Porter
# 4        True      True  Drinking a Mocha Milk Stout

# %%
# replace the string Drinking a with empty space
df_tweets['craft_beer'] = df_tweets.craft_beer.str.replace('Drinking a', '')

# %%
# replace n with empty space
df_tweets['craft_beer'] = df_tweets.craft_beer.str.replace('n ', '')

# %%
# write a function to print out 'beer not found' if the word Drinking was not found
def replace_na(text):
    final_len = len(text) 
    no_beer = 0
    
    if final_len == no_beer:
        return "no beer found"
    else:
        return text

# %%
# apply function to df
df_tweets['craft_beer'] = df_tweets.craft_beer.apply(replace_na)

# %%
# inspect head of df
df_tweets.head()
# Out:
#                   time                                              tweet  \
# 0  2018-08-19 01:51:15  RT @flyingbikecoop: 3rd Anniversary Party toda...
# 1  2018-08-18 23:40:58  Mystery keg #1 is tapped! Pitchfork is our wil...
# 2  2018-08-18 23:24:16  3 years old!! #proudmemberowner - Drinking a S...
# 3  2018-08-18 23:03:33  #MemberDrivenBeer celebrating 3 years! - Drink...
# 4  2018-08-18 22:26:25  #MemberDrivenBeer Stout Float :-D - Drinking a...
#
#                     id              source     city  \
# 0  1030995577981435906  Twitter for iPhone  Seattle
# 1  1030962792415866880           Instagram  Seattle
# 2  1030958589467406337             Untappd  Seattle
# 3  1030953374148165633             Untappd  Seattle
# 4  1030944029788332032             Untappd  Seattle
#
#                                          clean_tweet  tweet_len  retweet  \
# 0  rt flyingbikecoop rd anniversary party today b...        107     True
# 1  mystery keg tapped pitchfork wild golden stron...        145    False
# 2  years old proudmemberowner drinking storm cycl...        130    False
# 3  memberdrivenbeer celebrating years drinking cu...        134    False
# 4  memberdrivenbeer stout float drinking mocha mi...        133    False
#
#    at_brewery  drinking          craft_beer
# 0        True     False       no beer found
# 1       False     False       no beer found
# 2        True      True    Storm Cycle CDA
# 3        True      True       Curry Porter
# 4        True      True   Mocha Milk Stout

# %%
# inspect shape of df
df_tweets.shape
# Out:
# (6018, 11)

# %%
## save to local 
#df_tweets.to_csv("df_tweets.csv", index=False)
