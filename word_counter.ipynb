# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")
from sklearn.cluster import KMeans
import re
from pandas import Series
import csv
import glob

# %%
import urllib
import urllib.request
import urllib.parse

# %%
url_link = input("Enter url: ")
#url_link = 'https://thenextweb.com/artificial-intelligence/2018/04/09/cassie-kozyrkov-interview/'
import requests
r = requests.get(url_link)
r.text
# Out:
# Enter url: http://resonatebrewery.com
# '<!doctype html>\r\n<!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="en"> <![endif]-->\r\n<!--[if IE 7]> <html class="no-js lt-ie9 lt-ie8" lang="en"> <![endif]-->\r\n<!--[if IE 8]>  <html class="no-js lt-ie9" lang="en"> <![endif]-->\r\n<!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->\r\n<head>\r\n\t<meta charset="UTF-8">\r\n\t<meta name="viewport" content="width=device-width">\r\n<meta name="google-site-verification" content="ckBM26qiqUuCzpjVuriFAHHDU88KpQWJ-GwGVmUBdTw" />\r\n\t<title>Resonate Brewery | craft beer and artisanal pizza</title>\r\n\t<link rel="profile" href="http://gmpg.org/xfn/11">\r\n\t<link rel="pingback" href="http://resonatebrewery.com/xmlrpc.php" />\r\n\t<link rel=\'dns-prefetch\' href=\'//maps.googleapis.com\' />\n<link rel=\'dns-prefetch\' href=\'//fonts.googleapis.com\' />\n<link rel=\'dns-prefetch\' href=\'//s.w.org\' />\n<link rel="alternate" type="application/rss+xml" title="Resonate Brewery &raquo; Feed" href="http://resonatebrewery.com/feed/" />\n<link rel="alternate" type="application/rss+xml" title="Resonate Brewery &raquo; Comments Feed" href="http://resonatebrewery.com/comments/feed/" />\n<link rel="alternate" type="text/calendar" title="Resonate Brewery &raquo; iCal Feed" href="http://resonatebrewery.com/events/?ical=1" />\n<link rel="alternate" type="application/rss+xml" title="Resonate Brewery &raquo; Home Comments Feed" href="http://resonatebrewery.com/home/feed/" />\n\t\t<script type="text/javascript">\n\t\t\twindow._wpemojiSettings = {"baseUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/2.4\\/72x72\\/","ext":".png","svgUrl":"https:\\/\\/s.w.org\\/images\\/core\\/emoji\\/2.4\\/svg\\/","svgExt":".svg","source":{"concatemoji":"http:\\/\\/resonatebrewery.com\\/wp-includes\\/js\\/wp-emoji-release.min.js?ver=4.9.3"}};\n\t\t\t!function(a,b,c){function d(a,b){var c=String.fromCharCode;l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,a),0,0);var d=k.toDataURL();l.clearRect(0,0,k.width,k.height),l.fillText(c.apply(this,b),0,0);var e=k.toDataURL();return d===e}function e(a){var b;if(!l||!l.fillText)return!1;switch(l.textBaseline="top",l.font="600 32px Arial",a){case"flag":return!(b=d([55356,56826,55356,56819],[55356,56826,8203,55356,56819]))&&(b=d([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]),!b);case"emoji":return b=d([55357,56692,8205,9792,65039],[55357,56692,8203,9792,65039]),!b}return!1}function f(a){var c=b.createElement("script");c.src=a,c.defer=c.type="text/javascript",b.getElementsByTagName("head")[0].appendChild(c)}var g,h,i,j,k=b.createElement("canvas"),l=k.getContext&&k.getContext("2d");for(j=Array("flag","emoji"),c.supports={everything:!0,everythingExceptFlag:!0},i=0;i<j.length;i++)c.supports[j[i]]=e(j[i]),c.supports.everything=c.supports.everything&&c.supports[j[i]],"flag"!==j[i]&&(c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&c.supports[j[i]]);c.supports.everythingExceptFlag=c.supports.everythingExceptFlag&&!c.supports.flag,c.DOMReady=!1,c.readyCallback=function(){c.DOMReady=!0},c.supports.everything||(h=function(){c.readyCallback()},b.addEventListener?(b.addEventListener("DOMContentLoaded",h,!1),a.addEventListener("load",h,!1)):(a.attachEvent("onload",h),b.attachEvent("onreadystatechange",function(){"complete"===b.readyState&&c.readyCallback()})),g=c.source||{},g.concatemoji?f(g.concatemoji):g.wpemoji&&g.twemoji&&(f(g.twemoji),f(g.wpemoji)))}(window,document,window._wpemojiSettings);\n\t\t</script>\n\t\t<style type="text/css">\nimg.wp-smiley,\nimg.emoji {\n\tdisplay: inline !important;\n\tborder: none !important;\n\tbox-shadow: none !important;\n\theight: 1em !important;\n\twidth: 1em !important;\n\tmargin: 0 .07em !important;\n\tvertical-align: -0.1em !important;\n\tbackground: none !important;\n\tpadding: 0 !important;\n}\n</style>\n<link rel=\'stylesheet\'  ...

# %%
text_filtered = re.sub(r'<(.*?)>', '', r.text)

# %%
with open("url_text.txt", "w") as file:
    file.write(text_filtered)

# %%
def get_words(filename):
    with open(filename) as file:
        text = file.read()
        
    text = text.replace("\n", "")
    text = text.replace(",", " ")
    text = text.replace(".", " ")
    text = text.replace('"', " ")
    text = text.replace("/", " ")
    text = text.replace("-", " ")
    text = text.lower()
    
    words = text.split(" ")
    words.sort()
    return words

def get_unique_words(words):
    unique_words = []
    unique_words.append(words[0])
    
    for i in range(1, len(words)):
        if words[i] == words[i - 1]:
            continue
        else:
            unique_words.append(words[i])
    return unique_words

def main():
    filename = "list_categories.txt"
    print("The word count program")
    
    words = get_words(filename)
    unique_words = get_unique_words(words)
    
    print("number of words", len(words))
    print("number of unique words", len(unique_words))
    
    print("unique word occurences")
    for word in unique_words:
        print("  ", word, "=", words.count(word))
        
if __name__ == "__main__":
    main()
# Out:
# The word count program
# number of words 11460
# number of unique words 597
# unique word occurences
#     = 3871
#    (alcoholic) = 1
#    7 = 1
#    abernethy = 2
#    accepted = 1
#    accessories = 1
#    activities = 19
#    advertising = 1
#    agencies = 1
#    air = 3
#    airport = 7
#    alcoholic = 4
#    ale = 128
#    all = 1
#    aluminum = 2
#    american = 211
#    amusement = 3
#    analysis = 1
#    anne = 2
#    apparel = 1
#    arcades = 3
#    area = 1
#    arts = 5
#    at = 1
#    athmar = 1
#    attraction = 123
#    attractions = 5
#    auditoriums = 2
#    austin = 3
#    auto = 1
#    b = 1
#    baker = 3
#    ballard = 5
#    ballpark = 2
#    banquet = 14
#    bar = 221
#    barbecue = 9
#    barbershop = 1
#    barrio = 1
#    bars = 321
#    barton = 1
#    bath = 2
#    bay = 2
#    bbq = 5
#    beach = 2
#    beauty = 1
#    bed = 2
#    beer = 250
#    belgian = 1
#    belmar = 2
#    berkeley = 1
#    bernardo = 1
#    beverage = 46
#    beverages = 30
#    beverly = 1
#    bike = 3
#    billiards = 3
#    bistro = 1
#    bistros = 4
#    boat = 2
#    boggy = 1
#    boise = 2
#    bookstores = 1
#    boring = 1
#    bottled = 2
#    bottlers = 13
#    bottles = 1
#    bowmanville = 1
#    bread = 2
#    breakfast = 6
#    brew = 121
#    brewer = 21
#    breweries = 272
#    brewers = 276
#    brewery = 1088
#    brewing = 1
#    brewpub = 1
#    british = 4
#    brunch = 6
#    buckman = 3
#    buffet = 1
#    buildings = 2
#    bulk = 2
#    burger = 12
#    burgers = 6
#    burnet = 2
#    bus = 2
#    business = 13
#    buyers = 1
#    c = 1
#    cabarets = 1
#    cabinet = 1
#    cabinets = 1
#    caf = 4
#    cafes = 1
#    cajun = 1
#    cakes = 1
#    camera = 1
#    can = 1
#    canned = 3
#    capitol = 1
#    carry = 1
#    caterers = 7
#    catering = 5
#    cellular = 1
#    center = 3
#    centers = 7
#    central = 4
#    ceramics = 1
#    certified = 1
#    chain = 3
#    chapels = 1
#    cheese = 18
#    chemical = 1
#    chicago = 1
#    chicken = 1
#    children's = 1
#    chinatown = 1
#    chinaware = 2
#    chinese = 1
#    chips = 3
#    chiropractic = 2
#    chiropractors = 2
#    chop = 1
#    cider = 2
#    city = 8
#    civic = 1
#    classes = 4
#    cleaning = 2
#    clinics = 1
#    clothing = 8
#    club = 4
#    clubs = 178
#    cocktail = 6
#    coffee = 18
#    coffeehouses = 2
#    coin = 1
#    collectibles = 1
#    college = 1
#    colleges = 2
#    commerce = 3
#    commercial = 1
#    companies = 7
#    computers = 1
#    concert = 2
#    concession = 1
#    concessionaires = 1
#    concordia = 1
#    congress = 2
#    consultants = 15
#    consumer = 1
#    contractors = 3
#    convenience = 4
#    conventions = 1
#    cosmetics = 1
#    coupons = 1
#    crab = 1
#    crabs = 1
#    craft = 7
#    crafts = 4
#    creek = 1
#    creole = 1
#    curtis = 3
#    cyclical = 1
#    dairy = 2
#    dealers = 2
#    decoration = 2
#    deli = 1
#    delicatessens = 2
#    delis = 1
#    delridge = 1
#    denver = 4
#    deordorant = 3
#    depots = 2
#    design = 2
#    dessert = 2
#    desserts = 1
#    diego = 1
#    diner = 1
#    diners = 1
#    dining = 2
#    discount = 1
#    dispensing = 4
#    distilled = 3
#    distilleries = 1
#    distillers = 3
#    distillery = 21
#    distribution = 4
#    distributors = 35
#    district = 10
#    dive = 2
#    dog = 4
#    dogs = 1
#    downtown = 8
#    drilling = 1
#    drink = 70
#    drinks = 5
#    drugstore = 1
#    dry = 2
#    e = 3
#    east = 4
#    eliot = 3
#    emergency = 1
#    energy = 1
#    entertainment = 2
#    environment = 1
#    equipment = 55
#    ersonville = 3
#    espresso = 1
#    estate = 1
#    etc = 1
#    event = 6
#    events = 1
#    excursions = 3
#    extract = 6
#    extracts = 1
#    facilities = 13
#    family = 8
#    farm = 3
#    farmers' = 1
#    farms = 3
#    fast = 2
#    fasteners = 1
#    festival = 2
#    filtration = 2
#    first = 1
#    fish = 3
#    fitness = 2
#    five = 2
#    fixtures = 1
#    flashlight = 1
#    flavoring = 7
#    florists = 1
#    food = 115
#    foods = 11
#    foundation = 1
#    foundries = 1
#    free = 1
#    fremont = 1
#    french = 1
#    fresheners = 3
#    frozen = 4
#    fulton = 3
#    furniture = 2
#    galindo = 1
#    games = 1
#    garden = 73
#    gardens = 4
#    gas = 1
#    gastropub = 27
#    gate = 2
#    gateway = 1
#    general = 4
#    georgetown = 2
#    german = 3
#    gift = 6
#    glassware = 2
#    global = 1
#    glue = 3
#    gluten = 1
#    gold = 1
#    grant = 2
#    grantville = 2
#    green = 1
#    greenwood = 1
#    grill = 21
#    grills = 16
#    grocery = 41
#    guided = 2
#    h = 1
#    hall = 3
#    halls = 12
#    hamburger = 4
#    hamburgers = 1
#    hardware = 2
#    health = 7
#    heritage = 1
#    highl = 1
#    hill = 3
#    hills = 2
#    hillsdale = 1
#    historic = 1
#    historical = 1
#    ho = 1
#    hobbies = 3
#    hobby = 15
#    hollywood = 1
#    home = 2
#    homebrewing = 7
#    hosford = 2
#    hot = 5
#    hotel = 1
#    hotels = 18
#    house = 2
#    household = 1
#    houses = 2
#    hydroponics = 1
#    indian = 3
#    industrial = 7
#    information = 4
#    interbay = 1
#    interest = 1
#    interior = 2
#    international = 3
#    irish = 6
#    irving = 1
#    ise = 2
#    italian = 6
#    japanese = 1
#    jefferson = 1
#    jewelers = 1
#    jewelry = 2
#    joint = 20
#    juice = 9
#    karaoke = 5
#    kearny = 1
#    kerns = 3
#    kilbourn = 1
#    kitchen = 1
#    labeling = 1
#    laboratories = 4
#    laboratory = 1
#    lake = 3
#    lakeside = 1
#    lakeview = 1
#    latin = 1
#    laundry = 2
#    lee = 1
#    ling = 1
#    liquor = 40
#    lloyd = 2
#    lobbyists = 1
#    locations = 1
#    lockout = 1
#    locks = 5
#    locksmith = 1
#    locksmiths = 5
#    lodo = 2
#    logan = 2
#    loma = 1
#    loop = 1
#    lounge = 2
#    lounges = 2
#    lower = 1
#    lunch = 2
#    machine = 5
#    machines = 5
#    magazine = 1
#    makers = 2
#    management = 1
#    manicures = 2
#    manufacturers = 93
#    manufacturing = 2
#    mar = 1
#    market = 3
#    marketing = 5
#    markets = 2
#    mason = 1
#    materials = 2
#    meadowview = 1
#    medical = 1
#    men's = 1
#    merch = 2
#    mesa = 1
#    metal = 2
#    mexican = 11
#    mgmt = 2
#    microbreweries = 3
#    midway = 1
#    mills = 2
#    miramar = 6
#    miscellaneous = 5
#    mission = 3
#    money = 1
#    montavilla = 1
#    more = 9
#    morel = 1
#    morena = 1
#    motel = 1
#    motels = 18
#    movie = 10
#    multnomah = 1
#    music = 6
#    natural = 5
#    nature = 1
#    naval = 2
#    near = 4
#    neighborhood = 8
#    new = 6
#    newspaper = 1
#    night = 9
#    nightclubs = 5
#    nightlife = 130
#    non = 7
#    north = 15
#    northeast = 4
#    northwest = 3
#    ocean = 1
#    of = 1
#    office = 7
#    old = 3
#    online = 1
#    operators = 1
#    or = 1
#    orchards = 2
#    orchestras = 1
#    organizations = 2
#    other = 3
#    out = 5
#    outdoor = 6
#    overlook = 1
#    pacific = 1
#    packaging = 1
#    park = 28
#    parks = 2
#    parties = 1
#    parts = 1
#    party = 1
#    pearl = 3
#    pedicures = 2
#    performing = 5
#    pet = 1
#    pharmacies = 1
#    pharmacy = 3
#    phone = 1
#    piedmont = 1
#    pike = 1
#    pilsen = 1
#    pizza = 84
#    place = 42
#    places = 4
#    planners = 1
#    platinum = 1
#    platt = 2
#    points = 2
#    pool = 2
#    portal = 1
#    portl = 10
#    portsmouth = 1
#    prepared = 1
#    private = 3
#    produce = 2
#    product = 2
#    products = 4
#    profit = 6
#    promotional = 1
#    pub = 143
#    publishers = 2
#    pubs = 339
#    purification = 2
#    queen = 2
#    rafting = 1
#    raleigh = 1
#    ranch = 1
#    ranches = 2
#    rancho = 1
#    ravenswood = 2
#    real = 1
#    reception = 11
#    receptions = 1
#    recreation = 2
#    recycling = 3
#    reed = 1
#    referral = 2
#    rehabilitation = 1
#    rentals = 5
#    repair = 3
#    restaurant = 413
#    restaurant(r) = 1
#    restaurants = 278
#    retail = 48
#    river = 2
#    riverton = 1
#    rock = 2
#    rooms = 1
#    rose = 1
#    rosedale = 1
#    rosel = 1
#    s = 4
#    salad = 1
#    salads = 1
#    sales = 2
#    salon = 1
#    salons = 1
#    san = 1
#    school = 1
#    schools = 1
#    scrap = 2
#    scripps = 1
#    seafood = 10
#    seattle = 2
#    sellwood = 1
#    service = 6
#    services = 34
#    sewer = 1
#    shoe = 1
#    shoes = 1
#    shop = 55
#    shopping = 8
#    shops = 25
#    shortening = 1
#    side = 6
#    silver = 1
#    singles = 1
#    site = 1
#    sleepwear = 1
#    sloan = 1
#    smoothie = 2
#    snack = 3
#    soap = 3
#    soft = 3
#    solrjson:\\washington = 1
#    south = 2
#    spa = 3
#    space = 6
#    spas = 2
#    speakeasy = 2
#    specialty = 2
#    sports = 17
#    square = 2
#    staff = 1
#    stationery = 1
#    stations = 1
#    steak = 4
#    steakhouse = 5
#    store = 48
#    stores = 65
#    streeterville = 1
#    studio = 1
#    style = 7
#    sunnyside = 1
#    sunset = 1
#    super = 1
#    supermarket = 10
#    supermarkets = 18
#    supplies = 51
#    take = 4
#    tastings = 17
#    taverns = 33
#    tea = 10
#    telecommunications = 1
#    testing = 2
#    texas = 1
#    theater = 1
#    theaters = 9
#    tigard = 2
#    tour = 11
#    tourist = 3
#    tours = 109
#    town = 5
#    toys = 2
#    trade = 1
#    training = 2
#    transportation = 5
#    travel = 2
#    treatment = 1
#    tubing = 1
#    tx = 1
#    tx\\brewery = 1
#    union = 1
#    universities = 1
#    university = 1
#    upper = 1
#    valley = 3
#    valverde = 1
#    vanities = 1
#    vegan = 1
#    vegetarian = 6
#    vending = 10
#    venue = 11
#    venues = 2
#    video = 1
#    village = 1
#    vineyards = 4
#    walking = 1
#    watches = 2
#    water = 11
#    wedding = 4
#    wellness = 1
#    west = 9
#    whisky = 1
#    wholesale = 58
#    wholesalers = 2
#    wich = 3
#    wicker = 1
#    wildlife = 1
#    wine = 26
#    winemaking = 7
#    wineries = 77
#    winery = 11
#    wings = 4
#    women's = 1
#    woodlawn = 3
#    wrigleyville = 1
#    y = 1
#    yoga = 1
#    yogurt = 4
